# %%
# !pip install jsonpath
# Out:
# Collecting jsonpath
#   Downloading jsonpath-0.82.tar.gz (9.6 kB)
# Building wheels for collected packages: jsonpath
#   Building wheel for jsonpath (setup.py) ... done
#   Created wheel for jsonpath: filename=jsonpath-0.82-py3-none-any.whl size=5612 sha256=edd7ecaee26167bb5f24205eb4d20cadb33558bae2bfa8edc42557eb2f1f3d40
#   Stored in directory: /Users/sallywong/Library/Caches/pip/wheels/42/6a/ff/5a6f028a06347fbccf0e0ba7af11b20eb76b8c3e62382874af
# Successfully built jsonpath
# Installing collected packages: jsonpath
# Successfully installed jsonpath-0.82

# %%
import os
import re  # 正则表达式提取文本
from jsonpath import jsonpath  # 解析json数据
import requests  # 发送请求
import pandas as pd  # 存取csv文件
import datetime  # 转换时间用

# 请求头
headers = {
	"User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Mobile Safari/537.36",
	"accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
	"accept-encoding": "gzip, deflate, br",
}


def trans_time(v_str):
	"""转换GMT时间为标准格式"""
	GMT_FORMAT = '%a %b %d %H:%M:%S +0800 %Y'
	timeArray = datetime.datetime.strptime(v_str, GMT_FORMAT)
	ret_time = timeArray.strftime("%Y-%m-%d %H:%M:%S")
	return ret_time


def getLongText(v_id):
	"""爬取长微博全文"""
	url = 'https://m.weibo.cn/statuses/extend?id=' + str(v_id)
	r = requests.get(url, headers=headers)
	json_data = r.json()
	long_text = json_data['data']['longTextContent']
	# 微博内容-正则表达式数据清洗
	dr = re.compile(r'<[^>]+>', re.S)
	long_text2 = dr.sub('', long_text)
	# print(long_text2)
	return long_text2


def get_weibo_list(v_keyword, v_max_page):
	"""
	爬取微博内容列表
	:param v_keyword: 搜索关键字
	:param v_max_page: 爬取前几页
	:return: None
	"""
	for page in range(1, v_max_page + 1):
		print('===开始爬取第{}页微博==='.format(page))
		# 请求地址
		url = 'https://m.weibo.cn/api/container/getIndex'
		# 请求参数
		params = {
			"containerid": "100103type=1&q={}".format(v_keyword),
			"page_type": "searchall",
			"page": page
		}
		# 发送请求
		r = requests.get(url, headers=headers, params=params)
		print(r.status_code)
		# pprint(r.json())
		# 解析json数据
		cards = r.json()["data"]["cards"]
		# 微博内容
		text_list = jsonpath(cards, '$..mblog.text')
		# 微博内容-正则表达式数据清洗
		dr = re.compile(r'<[^>]+>', re.S)
		text2_list = []
		print('text_list is:')
		print(text_list)
		if not text_list:  # 如果未获取到微博内容，进入下一轮循环
			continue
		if type(text_list) == list and len(text_list) > 0:
			for text in text_list:
				text2 = dr.sub('', text)  # 正则表达式提取微博内容
				print(text2)
				text2_list.append(text2)
		# 微博创建时间
		time_list = jsonpath(cards, '$..mblog.created_at')
		time_list = [trans_time(v_str=i) for i in time_list]
		# 微博作者
		author_list = jsonpath(cards, '$..mblog.user.screen_name')
		# 微博id
		id_list = jsonpath(cards, '$..mblog.id')
		# 判断是否存在全文
		isLongText_list = jsonpath(cards, '$..mblog.isLongText')
		idx = 0
		for i in isLongText_list:
			if i == True:
				long_text = getLongText(v_id=id_list[idx])
				text2_list[idx] = long_text
			idx += 1
		# 转发数
		reposts_count_list = jsonpath(cards, '$..mblog.reposts_count')
		# 评论数
		comments_count_list = jsonpath(cards, '$..mblog.comments_count')
		# 点赞数
		attitudes_count_list = jsonpath(cards, '$..mblog.attitudes_count')
		# 把列表数据保存成DataFrame数据
		df = pd.DataFrame(
			{
				'页码': [page] * len(id_list),
				'微博id': id_list,
				'微博作者': author_list,
				'发布时间': time_list,
				'微博内容': text2_list,
				'转发数': reposts_count_list,
				'评论数': comments_count_list,
				'点赞数': attitudes_count_list,
			}
		)
		# 表头
		if os.path.exists(v_weibo_file):
			header = None
		else:
			header = ['页码', '微博id', '微博作者', '发布时间', '微博内容', '转发数', '评论数', '点赞数']  # csv文件头
		# 保存到csv文件
		df.to_csv(v_weibo_file, mode='a+', index=False, header=header, encoding='utf_8_sig')
		print('csv保存成功:{}'.format(v_weibo_file))


if __name__ == '__main__':
	# 爬取前几页
	max_search_page = 1  # 爬前n页
	# 爬取关键字
	search_keyword = '#普京决定在顿巴斯进行特别军事行动#'
	# 保存文件名
	v_weibo_file = '微博清单_{}_前{}页.csv'.format(search_keyword, max_search_page)
	# 如果csv文件存在，先删除之
	if os.path.exists(v_weibo_file):
		os.remove(v_weibo_file)
		print('微博清单存在，已删除: {}'.format(v_weibo_file))
	# 调用爬取微博函数
	get_weibo_list(v_keyword=search_keyword, v_max_page=max_search_page)
	# 数据清洗-去重
	df = pd.read_csv(v_weibo_file)
	# 删除重复数据
	df.drop_duplicates(subset=['微博id'], inplace=True, keep='first')
	# 再次保存csv文件
	df.to_csv(v_weibo_file, index=False, encoding='utf_8_sig')
	print('数据清洗完成')
# Out:
# ===开始爬取第1页微博===
# 200
# text_list is:
# ['【<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E6%99%AE%E4%BA%AC%E7%A7%B0%E4%B9%8C%E5%85%8B%E5%85%B0%E5%8A%A0%E5%85%A5%E5%8C%97%E7%BA%A6%E5%AE%8C%E5%85%A8%E4%B8%8D%E5%8F%AF%E6%8E%A5%E5%8F%97%23&extparam=%23%E6%99%AE%E4%BA%AC%E7%A7%B0%E4%B9%8C%E5%85%8B%E5%85%B0%E5%8A%A0%E5%85%A5%E5%8C%97%E7%BA%A6%E5%AE%8C%E5%85%A8%E4%B8%8D%E5%8F%AF%E6%8E%A5%E5%8F%97%23&luicode=10000011&lfid=100103type%3D1%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23" data-hide=""><span class="surl-text">#普京称乌克兰加入北约完全不可接受#</span></a> <a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23&extparam=%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23&luicode=10000011&lfid=100103type%3D1%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23" data-hide=""><span class="surl-text">#普京决定在顿巴斯进行特别军事行动#</span></a>】当地时间24日，俄罗斯总统<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E6%99%AE%E4%BA%AC%E5%B0%B1%E4%B9%8C%E5%85%8B%E5%85%B0%E5%B1%80%E5%8A%BF%E5%8F%91%E8%A1%A8%E7%B4%A7%E6%80%A5%E7%94%B5%E8%A7%86%E7%9B%B4%E6%92%AD%E8%AE%B2%E8%AF%9D%23&extparam=%23%E6%99%AE%E4%BA%AC%E5%B0%B1%E4%B9%8C%E5%85%8B%E5%85%B0%E5%B1%80%E5%8A%BF%E5%8F%91%E8%A1%A8%E7%B4%A7%E6%80%A5%E7%94%B5%E8%A7%86%E7%9B%B4%E6%92%AD%E8%AE%B2%E8%AF%9D%23&luicode=10000011&lfid=100103type%3D1%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23" data-hide=""><span class="surl-text">#普京就乌克兰局势发表紧急电视直播讲话#</span></a>时称，已决定在顿巴斯地区进行特别军事行动。他还表示，乌克兰加入北约是完全不可接受的。<a  href="https://weibo.cn/sinaurl?u=https%3A%2F%2Fcontent-static.cctvnews.cctv.com%2Fsnow-book%2Findex.html%3Ft%3D1645671574551%26toc_style_id%3Dfeeds_default%26share_to%3Dwechat%26track_id%3D2E88857B-7A34-4B15-9899-B2FB4DFACD9E_667364857932%26item_id%3D10692304900563335179" data-hide=""><span class=\'url-icon\'><img style=\'width: 1rem;height: 1rem\' src=\'https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_web_default.png\'></span><span class="surl-text">俄罗斯总统普京已决定在顿巴斯地区进行特别军事行动</span></a>（总台记者张誉耀）<a  href="https://video.weibo.com/show?fid=1034:4740363433476123" data-hide=""><span class=\'url-icon\'><img style=\'width: 1rem;height: 1rem\' src=\'https://h5.sinaimg.cn/upload/2015/09/25/3/timeline_card_small_video_default.png\'></span><span class="surl-text">央视新闻的微博视频</span></a> ', '【有消息称<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E4%BF%84%E5%86%9B%E7%AA%81%E7%A0%B4%E5%93%88%E5%B0%94%E7%A7%91%E5%A4%AB%E5%B7%9E%E7%95%8C%23&extparam=%23%E4%BF%84%E5%86%9B%E7%AA%81%E7%A0%B4%E5%93%88%E5%B0%94%E7%A7%91%E5%A4%AB%E5%B7%9E%E7%95%8C%23&luicode=10000011&lfid=100103type%3D1%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23" data-hide=""><span class="surl-text">#俄军突破哈尔科夫州界#</span></a>】当地时间24日，俄罗斯总统<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23&extparam=%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23&luicode=10000011&lfid=100103type%3D1%26q%3D%23%E6%99%AE%E4%BA%AC%E5%86%B3%E5%AE%9A%E5%9C%A8%E9%A1%BF%E5%B7%B4%E6%96%AF%E8%BF%9B%E8%A1%8C%E7%89%B9%E5%88%AB%E5%86%9B%E4%BA%8B%E8%A1%8C%E5%8A%A8%23" data-hide ...
# 【#普京称乌克兰加入北约完全不可接受# #普京决定在顿巴斯进行特别军事行动#】当地时间24日，俄罗斯总统#普京就乌克兰局势发表紧急电视直播讲话#时称，已决定在顿巴斯地区进行特别军事行动。他还表示，乌克兰加入北约是完全不可接受的。俄罗斯总统普京已决定在顿巴斯地区进行特别军事行动（总台记者张誉耀）央视新闻的微博视频
# 【有消息称#俄军突破哈尔科夫州界#】当地时间24日，俄罗斯总统#普京决定在顿巴斯进行特别军事行动#。 有消息称，#俄军已经登陆乌克兰敖德萨#，已突破哈尔科夫州界。@央视新闻
# 【#普京宣布在乌克兰开展军事行动#】据法新社报道，当地时间2月24日，俄罗斯总统普京宣布在乌克兰开展“军事行动”。 此前，乌克兰总统泽连斯基于当日发表电视讲话，再次呼吁与俄罗斯进行对话，以解决该地区不断发酵的危机。 泽连斯基说，他曾在当地时间23日致电普京，但没有成功。 ...全文
# 法国这一乱象也算是给欧洲各国敲响了警钟，毕竟同样的压力可不仅仅只存在于法国，几乎所有的欧洲国家都在面临通胀和能源危机，不醒悟就“死亡”。#普京决定在顿巴斯进行特别军事行动##普京宣布决定在顿涅茨克等四地实施战时状态#  夜聞会的微博视频
# 中国东北和乌克兰有什么共同点？  北边都有同一个俄罗斯大国的粮食主产区都有世界最肥沃的黑土地平原纬度都在38到55之间，气候相似 大国的重工军事生产研发地区计划经济的天花板曾经辉煌不在，低经济增长海岸线都在国家南部都被北边大国侵占过领土克里米亚和大连有相似的历史都 ...全文
# 俄乌战争（5）难舍基辅俄乌战争爆发以来，已有超过360万人成为难民，逃离乌克兰从而躲避战乱，但是也有很多人难舍家园，至今没有离开。一面是炮火下危机四伏的生活，一面是颠沛流离充满未知的逃亡路，他们时刻面临着两难的选择。#兵者凶器# #普京决定在顿巴斯进行特别军事行动# 时代草稿的微博视频
# 【全俄志愿者发起众筹 为顿巴斯武装力量采购物资装备】据俄媒报道，俄乌战事开始后，俄罗斯志愿者发起了一项名为“一切为了胜利”的众筹项目，为顿巴斯武装筹集资金、采购物资。#利西昌斯克# #关注俄乌局势最新进展# #普京决定在顿巴斯进行特别军事行动#  深圳卫视正午30分的微博视频
# 俄新战略方向！打响顿巴斯总决战！（下）#乌克兰局势##普京决定在顿巴斯进行特别军事行动#军事 54营地的微博视频
# csv保存成功:微博清单_#普京决定在顿巴斯进行特别军事行动#_前1页.csv
# 数据清洗完成
